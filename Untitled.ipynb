# %%
import pandas as pd
import numpy as np
import matplotlib as pyplot

# %%
df = pd.read_csv('./../testaquifer.csv')
df
# Out:
#      scalarAquiferStorageTrial\t
# 0                     0.00E+00\t
# 1                  0.170760051\t
# 2                     8.74E-02\t
# 3                     6.80E-02\t
# 4                     6.70E-02\t
# 5                     6.70E-02\t
# 6                     6.70E-02\t
# 7                     6.70E-02\t
# 8                  0.133757804\t
# 9                  0.105935208\t
# 10                 0.101666624\t
# 11                 0.101541872\t
# 12                  0.10154181\t
# 13                  0.10154181\t
# 14                 0.135793285\t
# 15                 0.124026777\t
# 16                 0.122831886\t
# 17                 0.122816835\t
# 18                 0.122816835\t
# 19                 0.143905375\t
# 20                 0.137835992\t
# 21                 0.137407727\t
# 22                 0.137405181\t
# 23                 0.137405181\t
# 24                 0.151850615\t
# 25                  0.14827915\t
# 26                 0.148094229\t
# ...

# %%
df['scalarAquiferStorageTrial'].plt()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scalarAquiferStorageTrial'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-87156b0b3e84> in <module>()
# ...
